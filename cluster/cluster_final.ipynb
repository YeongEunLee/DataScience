# %%
'''
클러스터 20431 순으로 좋음

계층5가 엑셀에는 2번으로 표시되어 있고
계층4가 엑셀에는 0번으로 표시되어 있음
...

계층1이 엑셀에는 1번으로 표시되어 있음
'''
# Out:
# '\n클러스터 20431 순으로 좋음\n\n계층5가 엑셀에는 2번으로 표시되어 있고\n계층4가 엑셀에는 0번으로 표시되어 있음\n...\n\n계층1이 엑셀에는 1번으로 표시되어 있음\n'

# %%
import pandas as pd
df = pd.read_excel('가번호_category.xlsx', sheet_name = 0)

# %%
df_전형 = df.groupby('전형').size()
df_전형
# Out:
# 전형
# KU교과우수자     88
# KU논술우수자    257
# KU자기추천     326
# 기타         325
# 수능         735
# dtype: int64

# %%
group_5 = df['category'] == 2
group_5 = df[group_5]
group_5
# Out:
#       Unnamed: 0       가번호  category   계열       전형  최종평점 성별     입학대학     입학학과  \
# 0              0  20154003         2  인문1   KU자기추천  3.96  여     문과대학   국어국문학과
# 3              3  20154016         2  인문1       수능  3.93  여     문과대학   국어국문학과
# 7              7  20154026         2  인문1       수능  3.86  여     문과대학   국어국문학과
# 8              8  20154027         2  인문1       수능  4.10  여     문과대학   국어국문학과
# 11            11  20154034         2  인문1  KU교과우수자  4.25  여     문과대학   국어국문학과
# ...          ...       ...       ...  ...      ...   ... ..      ...      ...
# 1699        1699  20167261         2  인문1       기타  4.04  여  글로벌융합대학  신산업융합학과
# 1710        1710  20167275         2  인문1       기타  4.11  여  글로벌융합대학  신산업융합학과
# 1718        1718  20167285         2  인문1       기타  3.85  여  글로벌융합대학  신산업융합학과
# 1724        1724  20167291         2  인문1       기타  4.14  여  글로벌융합대학  신산업융합학과
# 1730        1730  20167297         2  인문1       기타  3.83  여  글로벌융합대학  신산업융합학과
#
# ...

# %%
group_5_전형 = group_5.groupby('전형').size()
group_5_전형
# Out:
# 전형
# KU교과우수자     39
# KU논술우수자     41
# KU자기추천      88
# 기타          65
# 수능         152
# dtype: int64

# %%
group_5_입학대학 = group_5.groupby('입학대학').size()
group_5_입학대학
# Out:
# 입학대학
# 건축대학        13
# 경영대학        14
# 공과대학        39
# 글로벌융합대학     36
# 동물생명과학대학    26
# 문과대학        59
# 사범대학        42
# 상경대학        20
# 생명특성화대학     14
# 생명환경과학대학    20
# 수의과대학       25
# 예술디자인대학     26
# 이과대학        24
# 정보통신대학      11
# 정치대학        16
# dtype: int64

# %%
group_4 = df['category'] == 0
group_4 = df[group_4]

# %%
group_4_전형 = group_4.groupby('전형').size()

# %%
group_4_입학대학 = group_4.groupby('입학대학').size()

# %%
group_3 = df['category'] == 4
group_3 = df[group_3]

# %%
group_3_전형 = group_3.groupby('전형').size()

# %%
group_3_입학대학 = group_3.groupby('입학대학').size()

# %%
group_2 = df['category'] == 3
group_2 = df[group_2]

# %%
group_2_전형 = group_2.groupby('전형').size()

# %%
group_2_입학대학 = group_2.groupby('입학대학').size()

# %%
group_1 = df['category'] == 1
group_1 = df[group_1]

# %%
group_1_전형 = group_1.groupby('전형').size()

# %%
group_1_입학대학 = group_1.groupby('입학대학').size()

# %%
import pandas as pd
df_수시_정시 = pd.read_excel('전형구분_수시.xlsx', sheet_name = 0)
df_수시_정시
# Out:
#       Unnamed: 0       가번호 category   계열 전형구분       전형  최종평점 성별     입학대학  \
# 0              0  20154003   group5  인문1   수시   KU자기추천  3.96  여     문과대학
# 1              1  20154007   group2  인문1   수시  KU논술우수자  3.16  여     문과대학
# 2              2  20154015   group3  인문1   정시       수능  3.30  여     문과대학
# 3              3  20154016   group5  인문1   정시       수능  3.93  여     문과대학
# 4              4  20154018   group2  인문1   수시  KU논술우수자  3.37  여     문과대학
# ...          ...       ...      ...  ...  ...      ...   ... ..      ...
# 1726        1726  20167293   group2  인문1   기타       기타  3.61  여  글로벌융합대학
# 1727        1727  20167294   group1  인문1   기타       기타  2.76  남  글로벌융합대학
# 1728        1728  20167295   group2  인문1   기타       기타  3.27  여  글로벌융합대학
# 1729        1729  20167296   group4  인문1   기타       기타  3.45  여  글로벌융합대학
# 1730        1730  20167297   group5  인문1   기타       기타  3.83  여  글로벌융합대학
#
#          입학학과  ...  탐구과목2.1 탐구표준점수2  언어등급 수리등급  외국어등급 탐구영역구분.2  탐구과목1.2 탐구등급1  \
# ...

# %%
df_수시 = df_수시_정시['전형구분'] == '수시'
df_수시 = df_수시_정시[df_수시]
df_수시
# Out:
#       Unnamed: 0       가번호 category   계열 전형구분       전형  최종평점 성별     입학대학  \
# 0              0  20154003   group5  인문1   수시   KU자기추천  3.96  여     문과대학
# 1              1  20154007   group2  인문1   수시  KU논술우수자  3.16  여     문과대학
# 4              4  20154018   group2  인문1   수시  KU논술우수자  3.37  여     문과대학
# 6              6  20154025   group4  인문1   수시   KU자기추천  3.57  여     문과대학
# 9              9  20154030   group4  인문1   수시  KU논술우수자  3.39  여     문과대학
# ...          ...       ...      ...  ...  ...      ...   ... ..      ...
# 1670        1670  20167175   group4  인문1   수시  KU교과우수자  3.69  여  글로벌융합대학
# 1671        1671  20167183   group2  인문1   수시   KU자기추천  3.35  여  글로벌융합대학
# 1672        1672  20167194   group5  인문1   수시   KU자기추천  3.87  여  글로벌융합대학
# 1673        1673  20167213   group5  인문1   수시  KU논술우수자  3.92  여  글로벌융합대학
# 1674        1674  20167229   group4  인문1   수시  KU교과우수자  3.74  여  글로벌융합대학
#
#                 입학학과  ...  탐구과목2.1 탐구표준점수2  언어등급 수리등급  외국어등급 탐구영역구분.2  \
# ...

# %%
df_정시 = df_수시_정시['전형구분'] == '정시'
df_정시 = df_수시_정시[df_정시]
df_정시
# Out:
#       Unnamed: 0       가번호 category   계열 전형구분  전형  최종평점 성별     입학대학  \
# 2              2  20154015   group3  인문1   정시  수능  3.30  여     문과대학
# 3              3  20154016   group5  인문1   정시  수능  3.93  여     문과대학
# 5              5  20154020   group4  인문1   정시  수능  3.63  여     문과대학
# 7              7  20154026   group5  인문1   정시  수능  3.86  여     문과대학
# 8              8  20154027   group5  인문1   정시  수능  4.10  여     문과대학
# ...          ...       ...      ...  ...  ...  ..   ... ..      ...
# 1659        1659  20167104   group4  인문1   정시  수능  3.45  여     사범대학
# 1661        1661  20167109   group4  인문1   정시  수능  3.74  여     사범대학
# 1662        1662  20167110   group4  인문1   정시  수능  3.68  여     사범대학
# 1667        1667  20167133   group5  인문1   정시  수능  3.89  남  글로벌융합대학
# 1668        1668  20167157   group4  인문1   정시  수능  3.67  여  글로벌융합대학
#
#                 입학학과  ...  탐구과목2.1 탐구표준점수2  언어등급 수리등급  외국어등급 탐구영역구분.2  \
# 2             국어국문학과  ...    사회·문화    62.0   2.0  2.0    2.0       사탐
# ...

# %%
#group_4_입학대학 = group_4.groupby('입학대학').size()
df_수시_단과대 = df_수시.groupby('입학대학').size()
df_수시_단과대
# Out:
# 입학대학
# 건축대학         30
# 경영대학         31
# 공과대학        107
# 글로벌융합대학      24
# 동물생명과학대학     40
# 문과대학        105
# 사범대학         34
# 상경대학         45
# 생명특성화대학      29
# 생명환경과학대학     68
# 수의과대학        29
# 예술디자인대학      14
# 이과대학         50
# 정보통신대학       30
# 정치대학         35
# dtype: int64

# %%
df_정시_단과대 = df_정시.groupby('입학대학').size()
df_정시_단과대
# Out:
# 입학대학
# 건축대학         23
# 경영대학         36
# 공과대학         65
# 글로벌융합대학      11
# 동물생명과학대학     23
# 문과대학         46
# 사범대학         90
# 상경대학         37
# 생명특성화대학      12
# 생명환경과학대학     19
# 수의과대학        97
# 예술디자인대학     181
# 이과대학         32
# 정보통신대학       39
# 정치대학         24
# dtype: int64

# %%
df_수시_Group5 = df_수시['category'] == 'group5'
df_수시_Group5 = df_수시[df_수시_Group5]
df_수시_Group5
# Out:
#       Unnamed: 0       가번호 category   계열 전형구분       전형  최종평점 성별     입학대학  \
# 0              0  20154003   group5  인문1   수시   KU자기추천  3.96  여     문과대학
# 11            11  20154034   group5  인문1   수시  KU교과우수자  4.25  여     문과대학
# 15            15  20154038   group5  인문1   수시  KU교과우수자  3.96  여     문과대학
# 16            16  20154039   group5  인문1   수시   KU자기추천  3.83  여     문과대학
# 18            18  20154041   group5  인문1   수시   KU자기추천  3.94  여     문과대학
# ...          ...       ...      ...  ...  ...      ...   ... ..      ...
# 1648        1648  20167069   group5  인문1   수시   KU자기추천  3.85  여     사범대학
# 1650        1650  20167085   group5  인문1   수시   KU자기추천  3.79  남     사범대학
# 1658        1658  20167102   group5  인문1   수시   KU자기추천  4.27  여     사범대학
# 1672        1672  20167194   group5  인문1   수시   KU자기추천  3.87  여  글로벌융합대학
# 1673        1673  20167213   group5  인문1   수시  KU논술우수자  3.92  여  글로벌융합대학
#
#                 입학학과  ...  탐구과목2.1 탐구표준점수2  언어등급 수리등급  외국어등급 탐구영역구분.2  \
# ...

# %%
df_수시_group5_size = df_수시_Group5.groupby('입학대학').size()
df_수시_group5_size
# Out:
# 입학대학
# 건축대학         8
# 경영대학         4
# 공과대학        21
# 글로벌융합대학      6
# 동물생명과학대학    12
# 문과대학        35
# 사범대학        14
# 상경대학         9
# 생명특성화대학      8
# 생명환경과학대학    14
# 수의과대학        6
# 예술디자인대학      3
# 이과대학        15
# 정보통신대학       3
# 정치대학        10
# dtype: int64

# %%
df_수시_Group4 = df_수시['category'] == 'group4'
df_수시_Group4 = df_수시[df_수시_Group4]

df_수시_group4_size = df_수시_Group4.groupby('입학대학').size()
df_수시_group4_size
# Out:
# 입학대학
# 건축대학        16
# 경영대학        10
# 공과대학        34
# 글로벌융합대학      6
# 동물생명과학대학    15
# 문과대학        36
# 사범대학         9
# 상경대학        17
# 생명특성화대학     13
# 생명환경과학대학    25
# 수의과대학        8
# 예술디자인대학      4
# 이과대학        17
# 정보통신대학      16
# 정치대학        11
# dtype: int64

# %%
df_수시_Group3 = df_수시['category'] == 'group3'
df_수시_Group3 = df_수시[df_수시_Group3]

df_수시_group3_size = df_수시_Group3.groupby('입학대학').size()
df_수시_group3_size
# Out:
# 입학대학
# 건축대학         3
# 경영대학        10
# 공과대학        37
# 글로벌융합대학      2
# 동물생명과학대학     6
# 문과대학        17
# 사범대학         3
# 상경대학        14
# 생명특성화대학      6
# 생명환경과학대학    13
# 수의과대학        3
# 예술디자인대학      2
# 이과대학         2
# 정보통신대학       7
# 정치대학         4
# dtype: int64

# %%
df_수시_Group2 = df_수시['category'] == 'group2'
df_수시_Group2 = df_수시[df_수시_Group2]

df_수시_group2_size = df_수시_Group2.groupby('입학대학').size()
df_수시_group2_size
# Out:
# 입학대학
# 건축대학         1
# 경영대학         4
# 공과대학         7
# 글로벌융합대학      6
# 동물생명과학대학     5
# 문과대학        11
# 사범대학         8
# 상경대학         2
# 생명특성화대학      1
# 생명환경과학대학    12
# 수의과대학        7
# 예술디자인대학      5
# 이과대학        13
# 정보통신대학       3
# 정치대학         8
# dtype: int64

# %%
df_수시_Group1 = df_수시['category'] == 'group1'
df_수시_Group1 = df_수시[df_수시_Group1]

df_수시_group1_size = df_수시_Group1.groupby('입학대학').size()
df_수시_group1_size
# Out:
# 입학대학
# 건축대학        2
# 경영대학        3
# 공과대학        8
# 글로벌융합대학     4
# 동물생명과학대학    2
# 문과대학        6
# 상경대학        3
# 생명특성화대학     1
# 생명환경과학대학    4
# 수의과대학       5
# 이과대학        3
# 정보통신대학      1
# 정치대학        2
# dtype: int64

# %%
df_정시_Group5 = df_정시['category'] == 'group5'
df_정시_Group5 = df_정시[df_정시_Group5]

df_정시_group5_size = df_정시_Group5.groupby('입학대학').size()
df_정시_group5_size
# Out:
# 입학대학
# 건축대학         5
# 경영대학         6
# 공과대학        15
# 글로벌융합대학      4
# 동물생명과학대학     9
# 문과대학        18
# 사범대학        26
# 상경대학         9
# 생명특성화대학      4
# 생명환경과학대학     5
# 수의과대학       17
# 예술디자인대학     18
# 이과대학         6
# 정보통신대학       6
# 정치대학         4
# dtype: int64

# %%
df_정시_Group4 = df_정시['category'] == 'group4'
df_정시_Group4 = df_정시[df_정시_Group4]

df_정시_group4_size = df_정시_Group4.groupby('입학대학').size()
df_정시_group4_size
# Out:
# 입학대학
# 건축대학        10
# 경영대학        18
# 공과대학        20
# 글로벌융합대학      3
# 동물생명과학대학     9
# 문과대학        15
# 사범대학        30
# 상경대학         8
# 생명특성화대학      3
# 생명환경과학대학     4
# 수의과대학       21
# 예술디자인대학     49
# 이과대학         9
# 정보통신대학      15
# 정치대학         7
# dtype: int64

# %%
df_정시_Group3 = df_정시['category'] == 'group3'
df_정시_Group3 = df_정시[df_정시_Group3]

df_정시_group3_size = df_정시_Group3.groupby('입학대학').size()
df_정시_group3_size
# Out:
# 입학대학
# 건축대학         4
# 경영대학         9
# 공과대학        13
# 글로벌융합대학      2
# 동물생명과학대학     1
# 문과대학         5
# 사범대학         9
# 상경대학         7
# 생명특성화대학      3
# 생명환경과학대학     2
# 수의과대학       13
# 예술디자인대학     33
# 이과대학         9
# 정보통신대학      10
# 정치대학         7
# dtype: int64

# %%
df_정시_Group2 = df_정시['category'] == 'group2'
df_정시_Group2 = df_정시[df_정시_Group2]

df_정시_group2_size = df_정시_Group2.groupby('입학대학').size()
df_정시_group2_size
# Out:
# 입학대학
# 건축대학         4
# 경영대학         2
# 공과대학        11
# 글로벌융합대학      2
# 동물생명과학대학     2
# 문과대학         7
# 사범대학        21
# 상경대학         5
# 생명환경과학대학     8
# 수의과대학       29
# 예술디자인대학     51
# 이과대학         5
# 정보통신대학       5
# 정치대학         3
# dtype: int64

# %%
df_정시_Group1 = df_정시['category'] == 'group1'
df_정시_Group1 = df_정시[df_정시_Group1]

df_정시_group1_size = df_정시_Group1.groupby('입학대학').size()
df_정시_group1_size
# Out:
# 입학대학
# 경영대학         1
# 공과대학         6
# 동물생명과학대학     2
# 문과대학         1
# 사범대학         4
# 상경대학         8
# 생명특성화대학      2
# 수의과대학       17
# 예술디자인대학     30
# 이과대학         3
# 정보통신대학       3
# 정치대학         3
# dtype: int64

# %%
df_수시
# Out:
#       Unnamed: 0       가번호 category   계열 전형구분       전형  최종평점 성별     입학대학  \
# 0              0  20154003   group5  인문1   수시   KU자기추천  3.96  여     문과대학
# 1              1  20154007   group2  인문1   수시  KU논술우수자  3.16  여     문과대학
# 4              4  20154018   group2  인문1   수시  KU논술우수자  3.37  여     문과대학
# 6              6  20154025   group4  인문1   수시   KU자기추천  3.57  여     문과대학
# 9              9  20154030   group4  인문1   수시  KU논술우수자  3.39  여     문과대학
# ...          ...       ...      ...  ...  ...      ...   ... ..      ...
# 1670        1670  20167175   group4  인문1   수시  KU교과우수자  3.69  여  글로벌융합대학
# 1671        1671  20167183   group2  인문1   수시   KU자기추천  3.35  여  글로벌융합대학
# 1672        1672  20167194   group5  인문1   수시   KU자기추천  3.87  여  글로벌융합대학
# 1673        1673  20167213   group5  인문1   수시  KU논술우수자  3.92  여  글로벌융합대학
# 1674        1674  20167229   group4  인문1   수시  KU교과우수자  3.74  여  글로벌융합대학
#
#                 입학학과  ...  탐구과목2.1 탐구표준점수2  언어등급 수리등급  외국어등급 탐구영역구분.2  \
# ...

# %%
df_수시['언어등급'].corr(df_수시['수리등급'])
# Out:
# 0.05395231140242527

# %%
df_수시['언어등급'].corr(df_수시['외국어등급'])
# Out:
# 0.2966018391597631

# %%
df_수시['점수1'].corr(df_수시['국어평균등급'])
# Out:
# -0.4123924691225077

# %%
df_수시['점수1'].corr(df_수시['수학평균등급'])
# Out:
# -0.27756894151382033

# %%
df_수시['점수1'].corr(df_수시['영어평균등급'])
# Out:
# -0.4145883603678831

# %%
df_수시['점수1'].corr(df_수시['언어백분위'])
# Out:
# -0.041043818077769946

# %%
df_수시['점수1'].corr(df_수시['외국어백분위'])
# Out:
# -0.022548787059901626

# %%
df_수시['점수1'].corr(df_수시['수리백분위'])
# Out:
# -0.1426944493946629

# %%
df_수시['점수1'].corr(df_수시['탐구백분위1'])
# Out:
# -0.10187769974104142

# %%
df_수시['점수1'].corr(df_수시['탐구백분위2'])
# Out:
# -0.07897619743129054

# %%
df_수시['점수1'].corr(df_수시['탐구등급1'])
# Out:
# 0.1711360393806468

# %%
df_수시['점수1'].corr(df_수시['탐구등급2'])
# Out:
# 0.12067536411926037

# %%
df_수시_논술제외= df_수시[(df_수시['전형'] == 'KU자기추천') | (df_수시['전형'] == 'KU교과우수자')]
df_수시_논술제외
# Out:
#       Unnamed: 0       가번호 category   계열 전형구분       전형  최종평점 성별     입학대학  \
# 0              0  20154003   group5  인문1   수시   KU자기추천  3.96  여     문과대학
# 6              6  20154025   group4  인문1   수시   KU자기추천  3.57  여     문과대학
# 10            10  20154032   group4  인문1   수시   KU자기추천  3.35  여     문과대학
# 11            11  20154034   group5  인문1   수시  KU교과우수자  4.25  여     문과대학
# 14            14  20154037   group3  인문1   수시   KU자기추천  3.06  여     문과대학
# ...          ...       ...      ...  ...  ...      ...   ... ..      ...
# 1664        1664  20167122   group3  인문1   수시   KU자기추천  3.14  여  글로벌융합대학
# 1670        1670  20167175   group4  인문1   수시  KU교과우수자  3.69  여  글로벌융합대학
# 1671        1671  20167183   group2  인문1   수시   KU자기추천  3.35  여  글로벌융합대학
# 1672        1672  20167194   group5  인문1   수시   KU자기추천  3.87  여  글로벌융합대학
# 1674        1674  20167229   group4  인문1   수시  KU교과우수자  3.74  여  글로벌융합대학
#
#                 입학학과  ...  탐구과목2.1 탐구표준점수2  언어등급 수리등급  외국어등급 탐구영역구분.2  \
# ...

# %%
df_수시_논술제외_입학전형 = df_수시_논술제외.groupby('입학대학').size()
df_수시_논술제외_입학전형
# Out:
# 입학대학
# 건축대학        19
# 경영대학         8
# 공과대학        69
# 글로벌융합대학     14
# 동물생명과학대학    25
# 문과대학        62
# 사범대학        34
# 상경대학        24
# 생명특성화대학     19
# 생명환경과학대학    46
# 수의과대학       16
# 예술디자인대학     14
# 이과대학        31
# 정보통신대학      20
# 정치대학        13
# dtype: int64

# %%
df_수_논제외_Group5 = df_수시_논술제외['category'] == 'group5'
df_수_논제외_Group5 = df_수시_논술제외[df_수_논제외_Group5]

df_수시_group5_논술제외 = df_수_논제외_Group5.groupby('입학대학').size()
df_수시_group5_논술제외
# Out:
# 입학대학
# 건축대학         5
# 경영대학         1
# 공과대학        13
# 글로벌융합대학      4
# 동물생명과학대학    10
# 문과대학        26
# 사범대학        14
# 상경대학         6
# 생명특성화대학      8
# 생명환경과학대학    14
# 수의과대학        5
# 예술디자인대학      3
# 이과대학        10
# 정보통신대학       2
# 정치대학         6
# dtype: int64

# %%
df_수_논제외_Group4 = df_수시_논술제외['category'] == 'group4'
df_수_논제외_Group4 = df_수시_논술제외[df_수_논제외_Group4]

df_수시_group4_논술제외 = df_수_논제외_Group4.groupby('입학대학').size()
df_수시_group4_논술제외
# Out:
# 입학대학
# 건축대학        10
# 경영대학         1
# 공과대학        26
# 글로벌융합대학      5
# 동물생명과학대학     8
# 문과대학        20
# 사범대학         9
# 상경대학         9
# 생명특성화대학      8
# 생명환경과학대학    17
# 수의과대학        5
# 예술디자인대학      4
# 이과대학        11
# 정보통신대학      10
# 정치대학         6
# dtype: int64

# %%
df_수_논제외_Group3 = df_수시_논술제외['category'] == 'group3'
df_수_논제외_Group3 = df_수시_논술제외[df_수_논제외_Group3]

df_수시_group3_논술제외 = df_수_논제외_Group3.groupby('입학대학').size()
df_수시_group3_논술제외
# Out:
# 입학대학
# 건축대학         1
# 경영대학         3
# 공과대학        21
# 글로벌융합대학      1
# 동물생명과학대학     3
# 문과대학         8
# 사범대학         3
# 상경대학         7
# 생명특성화대학      2
# 생명환경과학대학     5
# 수의과대학        1
# 예술디자인대학      2
# 이과대학         2
# 정보통신대학       5
# dtype: int64

# %%
df_수_논제외_Group2 = df_수시_논술제외['category'] == 'group2'
df_수_논제외_Group2 = df_수시_논술제외[df_수_논제외_Group2]

df_수시_group2_논술제외 = df_수_논제외_Group2.groupby('입학대학').size()
df_수시_group2_논술제외
# Out:
# 입학대학
# 건축대학        1
# 경영대학        1
# 공과대학        4
# 글로벌융합대학     1
# 동물생명과학대학    3
# 문과대학        7
# 사범대학        8
# 상경대학        1
# 생명특성화대학     1
# 생명환경과학대학    6
# 수의과대학       5
# 예술디자인대학     5
# 이과대학        7
# 정보통신대학      2
# 정치대학        1
# dtype: int64

# %%
df_수_논제외_Group1 = df_수시_논술제외['category'] == 'group1'
df_수_논제외_Group1 = df_수시_논술제외[df_수_논제외_Group1]

df_수시_group1_논술제외 = df_수_논제외_Group1.groupby('입학대학').size()
df_수시_group1_논술제외
# Out:
# 입학대학
# 건축대학        2
# 경영대학        2
# 공과대학        5
# 글로벌융합대학     3
# 동물생명과학대학    1
# 문과대학        1
# 상경대학        1
# 생명환경과학대학    4
# 이과대학        1
# 정보통신대학      1
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import numpy as np
import random as rd

# %%
df = pd.read_excel('단과대cluster.xlsx', sheet_name = 1)

# %%
df.index = ['건축대학', '경영대학', '공과대학', '글로벌융합대학', '동물생명과학대학', '문과대학', '사범대학', '상경대학', '생명특성화대학', '생명환경과학대학', '이과대학', '정보통신대학', '정치대학']

# %%
df
# Out:
#           group5_수시  group5_정시  group4_수시  group4_정시  group3_수시  group3_정시  \
# 건축대학       0.263158   0.217391   0.526316   0.434783   0.052632   0.173913
# 경영대학       0.125000   0.166667   0.125000   0.500000   0.375000   0.250000
# 공과대학       0.188406   0.230769   0.376812   0.307692   0.304348   0.200000
# 글로벌융합대학    0.285714   0.363636   0.357143   0.272727   0.071429   0.181818
# 동물생명과학대학   0.400000   0.391304   0.320000   0.391304   0.120000   0.043478
# 문과대학       0.419355   0.391304   0.322581   0.326087   0.129032   0.108696
# 사범대학       0.411765   0.288889   0.264706   0.333333   0.088235   0.100000
# 상경대학       0.250000   0.243243   0.375000   0.216216   0.291667   0.189189
# 생명특성화대학    0.421053   0.333333   0.421053   0.250000   0.105263   0.250000
# 생명환경과학대학   0.304348   0.263158   0.369565   0.210526   0.108696   0.105263
# 이과대학       0.322581   0.187500   0.354839   0.281250   0.064516   0.281250
# ...

# %%
import platform
if platform.system() == 'Darwin':
    plt.rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
sns.set(style='whitegrid', font='AppleGothic', font_scale=1.2)

# %%
X = df.iloc[:,[1,2]].values
m = X.shape[0]
n = X.shape[1]

# %%
plt.scatter(X[:,0], X[:,1], c='black', label='입학대학')
plt.xlabel('입학대학')
# Out:
# Text(0.5, 0, '입학대학')

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import sklearn.linear_model as linear_model
import seaborn as sns
from sklearn.model_selection import KFold
from IPython.display import HTML, display
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit

# %%
from sklearn.preprocessing import scale

df_scaled = pd.DataFrame(scale(df), 
                            columns=df.columns)

# %%
from sklearn.preprocessing import scale

df_scaled_nodimension = pd.DataFrame(scale(df), 
                            columns=df.columns)

# %%
#pca = PCA(n_components=10)
#pca.fit(df_scaled)

#X_pca = pca.transform(df_scaled)
#print("원본 데이터 형태: {}".format(str(df_scaled.shape)))
#print("축소된 데이터 형태: {}".format(str(X_pca.shape)))
# Out:
# 원본 데이터 형태: (13, 10)
# 축소된 데이터 형태: (13, 10)

# %%
"""
import mglearn

plt.figure(figsize=(8,8))
mglearn.discrete_scatter(X_pca[:, 0], X_pca[:, 1])
plt.legend(["1st PCA", "2nd PCA"], loc="best")
plt.gca().set_aspect("equal")
plt.xlabel("첫 번째 주성분")
plt.ylabel("두 번째 주성분")
"""
# Out:
# Text(0, 0.5, '두 번째 주성분')

# %%
#print("PCA 주성분 형태: {}".format(pca.components_.shape))
# Out:
# PCA 주성분 형태: (10, 10)

# %%
# components_ 의 각 행은 주성분 하나씩을 나타내며 중요도에 따라 정렬
#print("PCA 주성분:\n{}".format(pca.components_))
# Out:
# PCA 주성분:
# [[-4.35077628e-01 -3.30817540e-01 -6.27907453e-02  2.78151059e-01
#    4.18953863e-01  3.73068208e-01 -2.14469731e-01 -3.36860523e-01
#    3.58309571e-01  1.31894916e-01]
#  [-1.98045565e-01  9.86162810e-02 -4.94179765e-01  3.92577931e-01
#    2.03097314e-01 -3.29014071e-01  3.36148722e-01  1.74660200e-01
#    1.12676129e-01 -4.97015970e-01]
#  [ 3.01110137e-01  5.83047081e-01 -2.29322826e-01  4.12481915e-02
#   -2.80234826e-03 -2.08590669e-01 -2.42369818e-01 -4.77084993e-01
#    4.02318061e-01  1.52864162e-01]
#  [ 2.75060902e-01 -1.76397079e-01 -4.46769080e-01 -3.70047694e-02
#    2.62357377e-02  2.31210532e-01  6.07256824e-01 -2.70277180e-01
#   -1.88122266e-01  4.01131390e-01]
#  [-2.31940761e-01  1.39625218e-01 -2.25723008e-01 -4.34056297e-01
#    5.75155470e-01 -3.03554151e-01 -1.57556511e-01  2.42137021e-01
#   -2.13802990e-01  3.67746502e-01]
#  [-2.51449385e-02  2.61968996e-02 -2.66042472e-01 -5.72698076e-01
# ...

# %%
"""
plt.plot(pca.explained_variance_ratio_)
plt.xlabel('number of components')
plt.ylabel('explained variance')
plt.show()
"""

# %%
"""
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()
"""

# %%
def pca_results(data, pca):
    # Dimension indexing
    dimensions = ['Dimension {}'.format(i) for i in range(1,len(pca.components_)+1)]
    
    # PCA components
    components = pd.DataFrame(np.round(pca.components_, 4), columns = data.keys()) 
    components.index = dimensions

    # PCA explained variance
    ratios = pca.explained_variance_ratio_.reshape(len(pca.components_), 1) 
    variance_ratios = pd.DataFrame(np.round(ratios, 4), columns = ['Explained Variance']) 
    variance_ratios.index = dimensions

    # Create a bar plot visualization
    fig, ax = plt.subplots(figsize = (14,8))

    # Plot the feature weights as a function of the components
    components.plot(ax = ax, kind = 'bar')
    ax.set_ylabel("Feature Weights") 
    ax.set_xticklabels(dimensions, rotation=0)

    # Display the explained variance ratios# 
    for i, ev in enumerate(pca.explained_variance_ratio_): 
        ax.text(i-0.40, ax.get_ylim()[1] + 0.05, "Explained Variance\n %.4f"%(ev))

    # Return a concatenated DataFrame
    return pd.concat([variance_ratios, components], axis = 1)

pca_results = pca_results(df_scaled, pca)
pca_results
# Out:
#               Explained Variance  group5_수시  group5_정시  group4_수시  group4_정시  \
# Dimension 1               0.3000    -0.4351    -0.3308    -0.0628     0.2782
# Dimension 2               0.2150    -0.1980     0.0986    -0.4942     0.3926
# Dimension 3               0.1625     0.3011     0.5830    -0.2293     0.0412
# Dimension 4               0.1156     0.2751    -0.1764    -0.4468    -0.0370
# Dimension 5               0.1085    -0.2319     0.1396    -0.2257    -0.4341
# Dimension 6               0.0676    -0.0251     0.0262    -0.2660    -0.5727
# Dimension 7               0.0200     0.4924    -0.3815    -0.4495     0.1442
# Dimension 8               0.0090     0.0295     0.3600    -0.0536    -0.1454
# Dimension 9               0.0018     0.5544    -0.0742     0.4159     0.0266
# Dimension 10              0.0000     0.0000     0.4571     0.0000     0.4543
#
#               group3_수시  group3_정시  group2_수시  group2_정시  group1_수시  group1_정시
# ...

# %%
pca_results.cumsum()
# Out:
#               Explained Variance  group5_수시  group5_정시  group4_수시  group4_정시  \
# Dimension 1               0.3000    -0.4351    -0.3308    -0.0628     0.2782
# Dimension 2               0.5150    -0.6331    -0.2322    -0.5570     0.6708
# Dimension 3               0.6775    -0.3320     0.3508    -0.7863     0.7120
# Dimension 4               0.7931    -0.0569     0.1744    -1.2331     0.6750
# Dimension 5               0.9016    -0.2888     0.3140    -1.4588     0.2409
# Dimension 6               0.9692    -0.3139     0.3402    -1.7248    -0.3318
# Dimension 7               0.9892     0.1785    -0.0413    -2.1743    -0.1876
# Dimension 8               0.9982     0.2080     0.3187    -2.2279    -0.3330
# Dimension 9               1.0000     0.7624     0.2445    -1.8120    -0.3064
# Dimension 10              1.0000     0.7624     0.7016    -1.8120     0.1479
#
#               group3_수시  group3_정시  group2_수시  group2_정시  group1_수시  group1_정시
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D

X = df_scaled_nodimension

kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
# print("클러스터 레이블:\n{}".format(kmeans.labels_))
y_kmeans = kmeans.predict(X)
print(y_kmeans)

# centers = kmeans.cluster_centers_
# centers
# Out:
# [1 3 1 1 2 2 2 1 1 2 0 1 0]

# %%
import mglearn

mglearn.discrete_scatter(X.values[:, 0], X.values[:, 1], kmeans.labels_, markers='o')
mglearn.discrete_scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], [0, 1, 2, 3], markers='^', markeredgewidth=2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# 두 개의 클러스터 중심을 사용합니다
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
assignments = kmeans.labels_

mglearn.discrete_scatter(X.values[:, 0], X.values[:, 1], assignments, ax=axes[0])

# 네 개의 클러스터 중심을 사용합니다
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
assignments = kmeans.labels_

mglearn.discrete_scatter(X.values[:, 0], X.values[:, 1], assignments, ax=axes[1])

# %%
data = df_scaled_nodimension
#pca = PCA(n_components=2).fit(data)
#reduced_data = pca.transform(data)
# pca_samples = pca.transform(data)
reduced_data = pd.DataFrame(data, columns = ['Dimension 1', 'Dimension 2','Dimension 3','Dimension 4', 'Dimension 5', 'Dimension 6', 'Dimension 7', 'Dimension 8','Dimension 9', 'Dimension 10'])

# %%
X = data
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

mglearn.discrete_scatter(X.values[:, 0], X.values[:, 1], kmeans.labels_, markers='o')
mglearn.discrete_scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], [0, 1, 2], markers='^', markeredgewidth=2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# 두 개의 클러스터 중심을 사용합니다
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
assignments = kmeans.labels_

mglearn.discrete_scatter(X.values[:, 0], X.values[:, 1], assignments, ax=axes[0])

# 네 개의 클러스터 중심을 사용합니다
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
assignments = kmeans.labels_

mglearn.discrete_scatter(X.values[:, 0], X.values[:, 1], assignments, ax=axes[1])

# %%
from scipy.cluster.hierarchy import dendrogram, ward

# X, y = make_blobs(random_state=0, n_samples=12)
linkage_array = ward(X)
dendrogram(linkage_array)

ax = plt.gca()
bounds = ax.get_xbound()
ax.plot(bounds, [10, 10], '--', c='k')
ax.plot(bounds, [5,5], '--', c='k')

ax.text(bounds[1], 10, '두 개 클러스터', va='center', fontdict={'size':15})
ax.text(bounds[1], 5, '네 개 클러스터', va='center', fontdict={'size':15})
plt.xlabel("샘플 번호")
plt.ylabel("클러스터 거리")
# Out:
# Text(0, 0.5, '클러스터 거리')
