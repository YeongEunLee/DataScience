# %%
import pandas as pd
import pymysql
import numpy as np

# %%
conn = pymysql.connect(host='chamaeleon.konkuk.ac.kr',
                       port = 3306,
                       user = "class_da",
                       password = "dataanalytics",
                       db = "tp_class_da")
cursor = conn.cursor()
cursor.execute("SELECT pt.특허등록번호 as pt_num, pt.특허제목 as pt_name, pt.보유IPC수 as ipc_num, ip.보유ipc전체코드 as ipc_code from us_patent pt inner join ipc ip on pt.특허등록번호 = ip.특허등록번호")
db = cursor.fetchall()
pt_list = []
for pt_num, pt_name, ipc_num, ipc_code in db:
    pt_list.append([pt_num, pt_name, ipc_num, ipc_code[0]])

for i in range(0, len(pt_new_list)):
    pt_ipc_num = pt_list[i][2]
# Out:
# [('9532496',
#   'Dynamic supplemental downforce control system for planter row units',
#   3,
#   'A01B'),
#  ('9532496',
#   'Dynamic supplemental downforce control system for planter row units',
#   3,
#   'A01B'),
#  ('9532496',
#   'Dynamic supplemental downforce control system for planter row units',
#   3,
#   'A01C'),
#  ('9532497',
#   'Variable precharge accumulator for agricultural header',
#   6,
#   'A01B'),
#  ('9532497',
#   'Variable precharge accumulator for agricultural header',
#   6,
#   'A01B'),
#  ('9532497',
#   'Variable precharge accumulator for agricultural header',
#   6,
#   'A01D'),
#  ('9532497',
#   'Variable precharge accumulator for agricultural header',
#   6,
#   'A01D'),
#  ('9532497',
#   'Variable precharge accumulator for agricultural header',
#   6,
#   'A01D'),
#  ('9532497',
#   'Variable precharge accumulator for agricultural header',
#   6,
#   'A01D'),
#  ('9532498', 'Seeder with lockout clutch', 5, 'A01B'),
# ...

# %%
cursor1 = conn.cursor()
cursor1.execute("SELECT ip.특허등록번호 as pt_num, ip.보유ipc전체코드 as ipc_code FROM ipc ip")
db1 = cursor1.fetchall()

pt_ipc_list = []
for pt_num, ipc_code in db1:
    pt_ipc_list.append([pt_num,ipc_code[0:4]])
pt_ipc_list
# Out:
# [['9532496', 'A01B'],
#  ['9532496', 'A01B'],
#  ['9532496', 'A01C'],
#  ['9532497', 'A01B'],
#  ['9532497', 'A01B'],
#  ['9532497', 'A01D'],
#  ['9532497', 'A01D'],
#  ['9532497', 'A01D'],
#  ['9532497', 'A01D'],
#  ['9532498', 'A01B'],
#  ['9532498', 'A01C'],
#  ['9532498', 'A01C'],
#  ['9532498', 'F16D'],
#  ['9532498', 'F16D'],
#  ['9532499', 'A01C'],
#  ['9532499', 'G06F'],
#  ['9532500', 'A01D'],
#  ['9532501', 'A01D'],
#  ['9532501', 'A01D'],
#  ['9532501', 'A01D'],
#  ['9532502', 'A01D'],
#  ['9532502', 'A01D'],
#  ['9532503', 'A01D'],
#  ['9532503', 'F16G'],
#  ['9532503', 'F16L'],
#  ['9532504', 'A01D'],
#  ['9532504', 'A01D'],
#  ['9532504', 'A01D'],
#  ['9532505', 'A01D'],
#  ['9532505', 'A01D'],
#  ['9532505', 'A01D'],
#  ['9532506', 'A01D'],
#  ['9532506', 'A01D'],
#  ['9532506', 'A01D'],
#  ['9532506', 'A01D'],
#  ['9532507', 'A01F'],
#  ['9532507', 'A01F'],
#  ['9532507', 'B30B'],
#  ['9532507', 'B30B'],
#  ['9532508', 'A01C'],
#  ['9532508', 'A01D'],
# ...

# %%
df = pandas
# Out:
# [['A01B'],
#  ['A01B'],
#  ['A01B'],
#  ['A01B'],
#  ['A01D'],
#  ['A01D'],
#  ['A01D'],
#  ['A01B'],
#  ['A01C'],
#  ['A01C'],
#  ['F16D'],
#  ['A01C'],
#  ['A01D'],
#  ['A01D'],
#  ['A01D'],
#  ['A01D'],
#  ['F16G'],
#  ['A01D'],
#  ['A01D'],
#  ['A01D'],
#  ['A01D'],
#  ['A01D'],
#  ['A01D'],
#  ['A01D'],
#  ['A01F'],
#  ['A01F'],
#  ['B30B'],
#  ['A01C'],
#  ['A01D'],
#  ['A01G'],
#  ['A01G'],
#  ['A01G'],
#  ['G05B'],
#  ['G06K'],
#  ['G06K'],
#  ['A01G'],
#  ['A01G'],
#  ['A01G'],
#  ['B23D'],
#  ['B23D'],
#  ['A01G'],
#  ['A01G'],
#  ['B29D'],
#  ['B29K'],
#  ['E04H'],
#  ['A01G'],
#  ['A01G'],
#  ['A01G'],
#  ['A01G'],
#  ['A01G'],
#  ['A01G'],
#  ['A01C'],
#  ['A01G'],
#  ['A01H'],
#  ['A01N'],
#  ['A01N'],
#  ['A01N'],
#  ['A01N'],
#  ['A01H'],
#  ['A01H'],
#  ['A01H'],
#  ['A01H'],
#  ['C12N'],
#  ['A01H'],
#  ['A01G'],
#  ['A01H'],
#  ['A01H'],
#  ['A01H'],
#  ['A01H'],
#  ['A01H'],
#  ['A01H'],
#  ['A01H'],
#  ['A01H'],
#  ['A01H'],
#  ['A01H'],
#  ['A01H'],
# ...
